# %%
from PyPDF2 import PdfReader
import re
import os

def clean_text_for_markdown_pypdf2(text):
    """Cleans text for better Markdown display, handling multiple newlines."""
    if text is None:
        return ""
    text = re.sub(r'\n\s*\n', '\n\n', text)  # Consolidate paragraph breaks
    text = re.sub(r'(?<!\n)\n(?!\n)', ' ', text)  # Replace single newlines with space
    return text.strip()

def pypdf2_to_markdown_chunks(pdf_path):
    """
    Extracts text from a PDF using PyPDF2 and splits it per page.
    
    Returns:
        list of str: Each string is a Markdown formatted page.
    """
    try:
        reader = PdfReader(pdf_path)
    except Exception as e:
        return [f"<!-- Error opening PDF {pdf_path}: {e} -->"]

    chunks = []
    for page_num, page in enumerate(reader.pages):
        page_md = f"\n## Page {page_num + 1}\n\n"
        try:
            # Extract and clean the page text
            page_text = page.extract_text()
            cleaned_text = clean_text_for_markdown_pypdf2(page_text)
            if cleaned_text:
                page_md += f"### Text on Page {page_num + 1}\n" + cleaned_text + "\n"
            else:
                page_md += f"<!-- No text found on Page {page_num + 1} -->\n"
        except Exception as e:
            page_md += f"<!-- Error extracting text from Page {page_num + 1}: {e} -->\n"
        chunks.append(page_md)
    return chunks

# --- Example Usage ---
if __name__ == "__main__":
    folder_path = "docs"  # Folder containing PDF files
    list_docs_md = []
    
    if not os.path.exists(folder_path):
        print(f"The folder '{folder_path}' does not exist. Please provide a valid folder path.")
    else:
        for file_name in os.listdir(folder_path):
            if file_name.endswith(".pdf"):
                pdf_file_path = os.path.join(folder_path, file_name)
                print(f"Processing file: {pdf_file_path}")
                # Get each page separately
                page_chunks = pypdf2_to_markdown_chunks(pdf_file_path)
                list_docs_md.extend(page_chunks)

    print("Total markdown chunks extracted:", len(list_docs_md))
# Out:
# Processing file: docs/Legge regionale n_37_2014 artt. 20-21-22.pdf
# Processing file: docs/Direttiva 2014_25_UE.pdf
# Processing file: docs/Direttiva 2014_23_UE.pdf
# Processing file: docs/Decreto Legislativo 7 marzo 2005_agg_L_147_2013.pdf
# Processing file: docs/L. 27 Dicembre 2006 n.296 (Finanziaria 2007).pdf
# Processing file: docs/L. 23 Dicembre 2000 n.388 (Finanziaria 2001).pdf
# Processing file: docs/dPR 5 ottobre 2010_207_agg_DM_infrastrutture_24apr2014.pdf
# Processing file: docs/Direttiva 2014_24_UE.pdf
# Processing file: docs/D.Lgs. 50_2016.pdf
# Processing file: docs/DGR_17_2024_01_22_signed_signed.pdf
# Processing file: docs/Decreto legislativo 12 aprile  2006_163_agg_DL_24apr2014_n_66.pdf
# Processing file: docs/L. 23 Dicembre 1999 n.488 (Finanziaria 2000).pdf
# Processing file: docs/BURP_n.177_del_17112008.pdf
# Processing file: docs/DELIBERAZIONE DELLA GIUNTA REGIONALE 21 marzo 2017 n_354.pdf
# Processing file: docs/Dir.1999 93 CE del Parlamento Europeo e del Consiglio.pdf
# Total markdown chunks extracted: 1332

# %%
import os

# Create an output directory for the text files
output_folder = "extracted_txt"
os.makedirs(output_folder, exist_ok=True)

# Save each markdown chunk as a separate text file
for idx, chunk in enumerate(list_docs_md):
    if chunk.strip():
        filename = f"chunk_{idx+1}.txt"
        file_path = os.path.join(output_folder, filename)
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(chunk)
        print(f"Saved chunk {idx+1} to {file_path}")
# Out:
# Saved chunk 1 to extracted_txt/chunk_1.txt
# Saved chunk 2 to extracted_txt/chunk_2.txt
# Saved chunk 3 to extracted_txt/chunk_3.txt
# Saved chunk 4 to extracted_txt/chunk_4.txt
# Saved chunk 5 to extracted_txt/chunk_5.txt
# Saved chunk 6 to extracted_txt/chunk_6.txt
# Saved chunk 7 to extracted_txt/chunk_7.txt
# Saved chunk 8 to extracted_txt/chunk_8.txt
# Saved chunk 9 to extracted_txt/chunk_9.txt
# Saved chunk 10 to extracted_txt/chunk_10.txt
# Saved chunk 11 to extracted_txt/chunk_11.txt
# Saved chunk 12 to extracted_txt/chunk_12.txt
# Saved chunk 13 to extracted_txt/chunk_13.txt
# Saved chunk 14 to extracted_txt/chunk_14.txt
# Saved chunk 15 to extracted_txt/chunk_15.txt
# Saved chunk 16 to extracted_txt/chunk_16.txt
# Saved chunk 17 to extracted_txt/chunk_17.txt
# Saved chunk 18 to extracted_txt/chunk_18.txt
# Saved chunk 19 to extracted_txt/chunk_19.txt
# Saved chunk 20 to extracted_txt/chunk_20.txt
# Saved chunk 21 to extracted_txt/chunk_21.txt
# Saved chunk 22 to extracted_txt/chunk_22.txt
# Saved chunk 23 to extracted_txt/chunk_23.txt
# Saved chunk 24 to extracted_txt/chunk_24.txt
# Saved chunk 25 to extracted_txt/chunk_25.txt
# Saved chunk 26 to extracted_txt/chunk_26.txt
# Saved chunk 27 to extracted_txt/chunk_27.txt
# Saved chunk 28 to extracted_txt/chunk_28.txt
# Saved chunk 29 to extracted_txt/chunk_29.txt
# Saved chunk 30 to extracted_txt/chunk_30.txt
# Saved chunk 31 to extracted_txt/chunk_31.txt
# Saved chunk 32 to extracted_txt/chunk_32.txt
# Saved chunk 33 to extracted_txt/chunk_33.txt
# Saved chunk 34 to extracted_txt/chunk_34.txt
# Saved chunk 35 to extracted_txt/chunk_35.txt
# Saved chunk 36 to extracted_txt/chunk_36.txt
# Saved chunk 37 to extracted_txt/chunk_37.txt
# Saved chunk 38 to extracted_txt/chunk_38.txt
# Saved chunk 39 to extracted_txt/chunk_39.txt
# Saved chunk 40 to extracted_txt/chunk_40.txt
# Saved chunk 41 to extracted_txt/chunk_41.txt
# Saved chunk 42 to extracted_txt/chunk_42.txt
# Saved chunk 43 to extracted_txt/chunk_43.txt
# Saved chunk 44 to extracted_txt/chunk_44.txt
# Saved chunk 45 to extracted_txt/chunk_45.txt
# Saved chunk 46 to extracted_txt/chunk_46.txt
# Saved chunk 47 to extracted_txt/chunk_47.txt
# Saved chunk 48 to extracted_txt/chunk_48.txt
# Saved chunk 49 to extracted_txt/chunk_49.txt
# Saved chunk 50 to extracted_txt/chunk_50.txt
# Saved chunk 51 to extracted_txt/chunk_51.txt
# Saved chunk 52 to extracted_txt/chunk_52.txt
# Saved chunk 53 to extracted_txt/chunk_53.txt
# Saved chunk 54 to extracted_txt/chunk_54.txt
# Saved chunk 55 to extracted_txt/chunk_55.txt
# Saved chunk 56 to extracted_txt/chunk_56.txt
# Saved chunk 57 to extracted_txt/chunk_57.txt
# Saved chunk 58 to extracted_txt/chunk_58.txt
# Saved chunk 59 to extracted_txt/chunk_59.txt
# Saved chunk 60 to extracted_txt/chunk_60.txt
# Saved chunk 61 to extracted_txt/chunk_61.txt
# Saved chunk 62 to extracted_txt/chunk_62.txt
# Saved chunk 63 to extracted_txt/chunk_63.txt
# Saved chunk 64 to extracted_txt/chunk_64.txt
# Saved chunk 65 to extracted_txt/chunk_65.txt
# Saved chunk 66 to extracted_txt/chunk_66.txt
# Saved chunk 67 to extracted_txt/chunk_67.txt
# Saved chunk 68 to extracted_txt/chunk_68.txt
# Saved chunk 69 to extracted_txt/chunk_69.txt
# Saved chunk 70 to extracted_txt/chunk_70.txt
# Saved chunk 71 to extracted_txt/chunk_71.txt
# Saved chunk 72 to extracted_txt/chunk_72.txt
# Saved chunk 73 to extracted_txt/chunk_73.txt
# Saved chunk 74 to extracted_txt/chunk_74.txt
# Saved chunk 75 to extracted_txt/chunk_75.txt
# Saved chunk 76 to extracted_txt/chunk_76.txt
# Saved chunk 77 to extracted_txt/chunk_77.txt
# Saved chunk 78 to extracted_txt/chunk_78.txt
# Saved chunk 79 to extracted_txt/chunk_79.txt
# Saved chunk 80 to extracted_txt/chunk_80.txt
# Saved chunk 81 to extracted_txt/chunk_81.txt
# Saved chunk 82 to extracted_txt/chunk_82.txt
# Saved chunk 83 to extracted_txt/chunk_83.txt
# Saved chunk 84 to extracted_txt/chunk_84.txt
# Saved chunk 85 to extracted_txt/chunk_85.txt
# Saved chunk 86 to extracted_txt/chunk_86.txt
# Saved chunk 87 to extracted_txt/chunk_87.txt
# Saved chunk 88 to extracted_txt/chunk_88.txt
# Saved chunk 89 to extracted_txt/chunk_89.txt
# Saved chunk 90 to extracted_txt/chunk_90.txt
# Saved chunk 91 to extracted_txt/chunk_91.txt
# Saved chunk 92 to extracted_txt/chunk_92.txt
# Saved chunk 93 to extracted_txt/chunk_93.txt
# Saved chunk 94 to extracted_txt/chunk_94.txt
# Saved chunk 95 to extracted_txt/chunk_95.txt
# Saved chunk 96 to extracted_txt/chunk_96.txt
# Saved chunk 97 to extracted_txt/chunk_97.txt
# Saved chunk 98 to extracted_txt/chunk_98.txt
# Saved chunk 99 to extracted_txt/chunk_99.txt
# Saved chunk 100 to extracted_txt/chunk_100.txt
# Saved chunk 101 to extracted_txt/chunk_101.txt
# Saved chunk 102 to extracted_txt/chunk_102.txt
# Saved chunk 103 to extracted_txt/chunk_103.txt
# Saved chunk 104 to extracted_txt/chunk_104.txt
# Saved chunk 105 to extracted_txt/chunk_105.txt
# Saved chunk 106 to extracted_txt/chunk_106.txt
# Saved chunk 107 to extracted_txt/chunk_107.txt
# Saved chunk 108 to extracted_txt/chunk_108.txt
# Saved chunk 109 to extracted_txt/chunk_109.txt
# Saved chunk 110 to extracted_txt/chunk_110.txt
# Saved chunk 111 to extracted_txt/chunk_111.txt
# Saved chunk 112 to extracted_txt/chunk_112.txt
# Saved chunk 113 to extracted_txt/chunk_113.txt
# Saved chunk 114 to extracted_txt/chunk_114.txt
# Saved chunk 115 to extracted_txt/chunk_115.txt
# Saved chunk 116 to extracted_txt/chunk_116.txt
# Saved chunk 117 to extracted_txt/chunk_117.txt
# Saved chunk 118 to extracted_txt/chunk_118.txt
# Saved chunk 119 to extracted_txt/chunk_119.txt
# Saved chunk 120 to extracted_txt/chunk_120.txt
# Saved chunk 121 to extracted_txt/chunk_121.txt
# Saved chunk 122 to extracted_txt/chunk_122.txt
# Saved chunk 123 to extracted_txt/chunk_123.txt
# Saved chunk 124 to extracted_txt/chunk_124.txt
# Saved chunk 125 to extracted_txt/chunk_125.txt
# Saved chunk 126 to extracted_txt/chunk_126.txt
# Saved chunk 127 to extracted_txt/chunk_127.txt
# Saved chunk 128 to extracted_txt/chunk_128.txt
# Saved chunk 129 to extracted_txt/chunk_129.txt
# Saved chunk 130 to extracted_txt/chunk_130.txt
# Saved chunk 131 to extracted_txt/chunk_131.txt
# Saved chunk 132 to extracted_txt/chunk_132.txt
# Saved chunk 133 to extracted_txt/chunk_133.txt
# Saved chunk 134 to extracted_txt/chunk_134.txt
# Saved chunk 135 to extracted_txt/chunk_135.txt
# Saved chunk 136 to extracted_txt/chunk_136.txt
# Saved chunk 137 to extracted_txt/chunk_137.txt
# Saved chunk 138 to extracted_txt/chunk_138.txt
# Saved chunk 139 to extracted_txt/chunk_139.txt
# Saved chunk 140 to extracted_txt/chunk_140.txt
# Saved chunk 141 to extracted_txt/chunk_141.txt
# Saved chunk 142 to extracted_txt/chunk_142.txt
# Saved chunk 143 to extracted_txt/chunk_143.txt
# Saved chunk 144 to extracted_txt/chunk_144.txt
# Saved chunk 145 to extracted_txt/chunk_145.txt
# Saved chunk 146 to extracted_txt/chunk_146.txt
# Saved chunk 147 to extracted_txt/chunk_147.txt
# Saved chunk 148 to extracted_txt/chunk_148.txt
# Saved chunk 149 to extracted_txt/chunk_149.txt
# Saved chunk 150 to extracted_txt/chunk_150.txt
# Saved chunk 151 to extracted_txt/chunk_151.txt
# Saved chunk 152 to extracted_txt/chunk_152.txt
# Saved chunk 153 to extracted_txt/chunk_153.txt
# Saved chunk 154 to extracted_txt/chunk_154.txt
# Saved chunk 155 to extracted_txt/chunk_155.txt
# Saved chunk 156 to extracted_txt/chunk_156.txt
# Saved chunk 157 to extracted_txt/chunk_157.txt
# Saved chunk 158 to extracted_txt/chunk_158.txt
# Saved chunk 159 to extracted_txt/chunk_159.txt
# Saved chunk 160 to extracted_txt/chunk_160.txt
# Saved chunk 161 to extracted_txt/chunk_161.txt
# Saved chunk 162 to extracted_txt/chunk_162.txt
# Saved chunk 163 to extracted_txt/chunk_163.txt
# Saved chunk 164 to extracted_txt/chunk_164.txt
# Saved chunk 165 to extracted_txt/chunk_165.txt
# Saved chunk 166 to extracted_txt/chunk_166.txt
# Saved chunk 167 to extracted_txt/chunk_167.txt
# Saved chunk 168 to extracted_txt/chunk_168.txt
# Saved chunk 169 to extracted_txt/chunk_169.txt
# Saved chunk 170 to extracted_txt/chunk_170.txt
# Saved chunk 171 to extracted_txt/chunk_171.txt
# Saved chunk 172 to extracted_txt/chunk_172.txt
# Saved chunk 173 to extracted_txt/chunk_173.txt
# Saved chunk 174 to extracted_txt/chunk_174.txt
# Saved chunk 175 to extracted_txt/chunk_175.txt
# Saved chunk 176 to extracted_txt/chunk_176.txt
# Saved chunk 177 to extracted_txt/chunk_177.txt
# Saved chunk 178 to extracted_txt/chunk_178.txt
# Saved chunk 179 to extracted_txt/chunk_179.txt
# Saved chunk 180 to extracted_txt/chunk_180.txt
# Saved chunk 181 to extracted_txt/chunk_181.txt
# Saved chunk 182 to extracted_txt/chunk_182.txt
# Saved chunk 183 to extracted_txt/chunk_183.txt
# Saved chunk 184 to extracted_txt/chunk_184.txt
# Saved chunk 185 to extracted_txt/chunk_185.txt
# Saved chunk 186 to extracted_txt/chunk_186.txt
# Saved chunk 187 to extracted_txt/chunk_187.txt
# Saved chunk 188 to extracted_txt/chunk_188.txt
# Saved chunk 189 to extracted_txt/chunk_189.txt
# Saved chunk 190 to extracted_txt/chunk_190.txt
# Saved chunk 191 to extracted_txt/chunk_191.txt
# Saved chunk 192 to extracted_txt/chunk_192.txt
# Saved chunk 193 to extracted_txt/chunk_193.txt
# Saved chunk 194 to extracted_txt/chunk_194.txt
# Saved chunk 195 to extracted_txt/chunk_195.txt
# Saved chunk 196 to extracted_txt/chunk_196.txt
# Saved chunk 197 to extracted_txt/chunk_197.txt
# Saved chunk 198 to extracted_txt/chunk_198.txt
# Saved chunk 199 to extracted_txt/chunk_199.txt
# Saved chunk 200 to extracted_txt/chunk_200.txt
# Saved chunk 201 to extracted_txt/chunk_201.txt
# Saved chunk 202 to extracted_txt/chunk_202.txt
# Saved chunk 203 to extracted_txt/chunk_203.txt
# Saved chunk 204 to extracted_txt/chunk_204.txt
# Saved chunk 205 to extracted_txt/chunk_205.txt
# Saved chunk 206 to extracted_txt/chunk_206.txt
# Saved chunk 207 to extracted_txt/chunk_207.txt
# Saved chunk 208 to extracted_txt/chunk_208.txt
# Saved chunk 209 to extracted_txt/chunk_209.txt
# Saved chunk 210 to extracted_txt/chunk_210.txt
# Saved chunk 211 to extracted_txt/chunk_211.txt
# Saved chunk 212 to extracted_txt/chunk_212.txt
# Saved chunk 213 to extracted_txt/chunk_213.txt
# Saved chunk 214 to extracted_txt/chunk_214.txt
# Saved chunk 215 to extracted_txt/chunk_215.txt
# Saved chunk 216 to extracted_txt/chunk_216.txt
# Saved chunk 217 to extracted_txt/chunk_217.txt
# Saved chunk 218 to extracted_txt/chunk_218.txt
# Saved chunk 219 to extracted_txt/chunk_219.txt
# Saved chunk 220 to extracted_txt/chunk_220.txt
# Saved chunk 221 to extracted_txt/chunk_221.txt
# Saved chunk 222 to extracted_txt/chunk_222.txt
# Saved chunk 223 to extracted_txt/chunk_223.txt
# Saved chunk 224 to extracted_txt/chunk_224.txt
# Saved chunk 225 to extracted_txt/chunk_225.txt
# Saved chunk 226 to extracted_txt/chunk_226.txt
# Saved chunk 227 to extracted_txt/chunk_227.txt
# Saved chunk 228 to extracted_txt/chunk_228.txt
# Saved chunk 229 to extracted_txt/chunk_229.txt
# Saved chunk 230 to extracted_txt/chunk_230.txt
# Saved chunk 231 to extracted_txt/chunk_231.txt
# Saved chunk 232 to extracted_txt/chunk_232.txt
# Saved chunk 233 to extracted_txt/chunk_233.txt
# Saved chunk 234 to extracted_txt/chunk_234.txt
# Saved chunk 235 to extracted_txt/chunk_235.txt
# Saved chunk 236 to extracted_txt/chunk_236.txt
# Saved chunk 237 to extracted_txt/chunk_237.txt
# Saved chunk 238 to extracted_txt/chunk_238.txt
# Saved chunk 239 to extracted_txt/chunk_239.txt
# Saved chunk 240 to extracted_txt/chunk_240.txt
# Saved chunk 241 to extracted_txt/chunk_241.txt
# Saved chunk 242 to extracted_txt/chunk_242.txt
# Saved chunk 243 to extracted_txt/chunk_243.txt
# Saved chunk 244 to extracted_txt/chunk_244.txt
# Saved chunk 245 to extracted_txt/chunk_245.txt
# Saved chunk 246 to extracted_txt/chunk_246.txt
# Saved chunk 247 to extracted_txt/chunk_247.txt
# Saved chunk 248 to extracted_txt/chunk_248.txt
# Saved chunk 249 to extracted_txt/chunk_249.txt
# Saved chunk 250 to extracted_txt/chunk_250.txt
# Saved chunk 251 to extracted_txt/chunk_251.txt
# Saved chunk 252 to extracted_txt/chunk_252.txt
# Saved chunk 253 to extracted_txt/chunk_253.txt
# Saved chunk 254 to extracted_txt/chunk_254.txt
# Saved chunk 255 to extracted_txt/chunk_255.txt
# Saved chunk 256 to extracted_txt/chunk_256.txt
# Saved chunk 257 to extracted_txt/chunk_257.txt
# Saved chunk 258 to extracted_txt/chunk_258.txt
# Saved chunk 259 to extracted_txt/chunk_259.txt
# Saved chunk 260 to extracted_txt/chunk_260.txt
# Saved chunk 261 to extracted_txt/chunk_261.txt
# Saved chunk 262 to extracted_txt/chunk_262.txt
# Saved chunk 263 to extracted_txt/chunk_263.txt
# Saved chunk 264 to extracted_txt/chunk_264.txt
# Saved chunk 265 to extracted_txt/chunk_265.txt
# Saved chunk 266 to extracted_txt/chunk_266.txt
# Saved chunk 267 to extracted_txt/chunk_267.txt
# Saved chunk 268 to extracted_txt/chunk_268.txt
# Saved chunk 269 to extracted_txt/chunk_269.txt
# Saved chunk 270 to extracted_txt/chunk_270.txt
# Saved chunk 271 to extracted_txt/chunk_271.txt
# Saved chunk 272 to extracted_txt/chunk_272.txt
# Saved chunk 273 to extracted_txt/chunk_273.txt
# Saved chunk 274 to extracted_txt/chunk_274.txt
# Saved chunk 275 to extracted_txt/chunk_275.txt
# Saved chunk 276 to extracted_txt/chunk_276.txt
# Saved chunk 277 to extracted_txt/chunk_277.txt
# Saved chunk 278 to extracted_txt/chunk_278.txt
# Saved chunk 279 to extracted_txt/chunk_279.txt
# Saved chunk 280 to extracted_txt/chunk_280.txt
# Saved chunk 281 to extracted_txt/chunk_281.txt
# Saved chunk 282 to extracted_txt/chunk_282.txt
# Saved chunk 283 to extracted_txt/chunk_283.txt
# Saved chunk 284 to extracted_txt/chunk_284.txt
# Saved chunk 285 to extracted_txt/chunk_285.txt
# Saved chunk 286 to extracted_txt/chunk_286.txt
# Saved chunk 287 to extracted_txt/chunk_287.txt
# Saved chunk 288 to extracted_txt/chunk_288.txt
# Saved chunk 289 to extracted_txt/chunk_289.txt
# Saved chunk 290 to extracted_txt/chunk_290.txt
# Saved chunk 291 to extracted_txt/chunk_291.txt
# Saved chunk 292 to extracted_txt/chunk_292.txt
# Saved chunk 293 to extracted_txt/chunk_293.txt
# Saved chunk 294 to extracted_txt/chunk_294.txt
# Saved chunk 295 to extracted_txt/chunk_295.txt
# Saved chunk 296 to extracted_txt/chunk_296.txt
# Saved chunk 297 to extracted_txt/chunk_297.txt
# Saved chunk 298 to extracted_txt/chunk_298.txt
# Saved chunk 299 to extracted_txt/chunk_299.txt
# Saved chunk 300 to extracted_txt/chunk_300.txt
# Saved chunk 301 to extracted_txt/chunk_301.txt
# Saved chunk 302 to extracted_txt/chunk_302.txt
# Saved chunk 303 to extracted_txt/chunk_303.txt
# Saved chunk 304 to extracted_txt/chunk_304.txt
# Saved chunk 305 to extracted_txt/chunk_305.txt
# Saved chunk 306 to extracted_txt/chunk_306.txt
# Saved chunk 307 to extracted_txt/chunk_307.txt
# Saved chunk 308 to extracted_txt/chunk_308.txt
# Saved chunk 309 to extracted_txt/chunk_309.txt
# Saved chunk 310 to extracted_txt/chunk_310.txt
# Saved chunk 311 to extracted_txt/chunk_311.txt
# Saved chunk 312 to extracted_txt/chunk_312.txt
# Saved chunk 313 to extracted_txt/chunk_313.txt
# Saved chunk 314 to extracted_txt/chunk_314.txt
# Saved chunk 315 to extracted_txt/chunk_315.txt
# Saved chunk 316 to extracted_txt/chunk_316.txt
# Saved chunk 317 to extracted_txt/chunk_317.txt
# Saved chunk 318 to extracted_txt/chunk_318.txt
# Saved chunk 319 to extracted_txt/chunk_319.txt
# Saved chunk 320 to extracted_txt/chunk_320.txt
# Saved chunk 321 to extracted_txt/chunk_321.txt
# Saved chunk 322 to extracted_txt/chunk_322.txt
# Saved chunk 323 to extracted_txt/chunk_323.txt
# Saved chunk 324 to extracted_txt/chunk_324.txt
# Saved chunk 325 to extracted_txt/chunk_325.txt
# Saved chunk 326 to extracted_txt/chunk_326.txt
# Saved chunk 327 to extracted_txt/chunk_327.txt
# Saved chunk 328 to extracted_txt/chunk_328.txt
# Saved chunk 329 to extracted_txt/chunk_329.txt
# Saved chunk 330 to extracted_txt/chunk_330.txt
# Saved chunk 331 to extracted_txt/chunk_331.txt
# Saved chunk 332 to extracted_txt/chunk_332.txt
# Saved chunk 333 to extracted_txt/chunk_333.txt
# Saved chunk 334 to extracted_txt/chunk_334.txt
# Saved chunk 335 to extracted_txt/chunk_335.txt
# Saved chunk 336 to extracted_txt/chunk_336.txt
# Saved chunk 337 to extracted_txt/chunk_337.txt
# Saved chunk 338 to extracted_txt/chunk_338.txt
# Saved chunk 339 to extracted_txt/chunk_339.txt
# Saved chunk 340 to extracted_txt/chunk_340.txt
# Saved chunk 341 to extracted_txt/chunk_341.txt
# Saved chunk 342 to extracted_txt/chunk_342.txt
# Saved chunk 343 to extracted_txt/chunk_343.txt
# Saved chunk 344 to extracted_txt/chunk_344.txt
# Saved chunk 345 to extracted_txt/chunk_345.txt
# Saved chunk 346 to extracted_txt/chunk_346.txt
# Saved chunk 347 to extracted_txt/chunk_347.txt
# Saved chunk 348 to extracted_txt/chunk_348.txt
# Saved chunk 349 to extracted_txt/chunk_349.txt
# Saved chunk 350 to extracted_txt/chunk_350.txt
# Saved chunk 351 to extracted_txt/chunk_351.txt
# Saved chunk 352 to extracted_txt/chunk_352.txt
# Saved chunk 353 to extracted_txt/chunk_353.txt
# Saved chunk 354 to extracted_txt/chunk_354.txt
# Saved chunk 355 to extracted_txt/chunk_355.txt
# Saved chunk 356 to extracted_txt/chunk_356.txt
# Saved chunk 357 to extracted_txt/chunk_357.txt
# Saved chunk 358 to extracted_txt/chunk_358.txt
# Saved chunk 359 to extracted_txt/chunk_359.txt
# Saved chunk 360 to extracted_txt/chunk_360.txt
# Saved chunk 361 to extracted_txt/chunk_361.txt
# Saved chunk 362 to extracted_txt/chunk_362.txt
# Saved chunk 363 to extracted_txt/chunk_363.txt
# Saved chunk 364 to extracted_txt/chunk_364.txt
# Saved chunk 365 to extracted_txt/chunk_365.txt
# Saved chunk 366 to extracted_txt/chunk_366.txt
# Saved chunk 367 to extracted_txt/chunk_367.txt
# Saved chunk 368 to extracted_txt/chunk_368.txt
# Saved chunk 369 to extracted_txt/chunk_369.txt
# Saved chunk 370 to extracted_txt/chunk_370.txt
# Saved chunk 371 to extracted_txt/chunk_371.txt
# Saved chunk 372 to extracted_txt/chunk_372.txt
# Saved chunk 373 to extracted_txt/chunk_373.txt
# Saved chunk 374 to extracted_txt/chunk_374.txt
# Saved chunk 375 to extracted_txt/chunk_375.txt
# Saved chunk 376 to extracted_txt/chunk_376.txt
# Saved chunk 377 to extracted_txt/chunk_377.txt
# Saved chunk 378 to extracted_txt/chunk_378.txt
# Saved chunk 379 to extracted_txt/chunk_379.txt
# Saved chunk 380 to extracted_txt/chunk_380.txt
# Saved chunk 381 to extracted_txt/chunk_381.txt
# Saved chunk 382 to extracted_txt/chunk_382.txt
# Saved chunk 383 to extracted_txt/chunk_383.txt
# Saved chunk 384 to extracted_txt/chunk_384.txt
# Saved chunk 385 to extracted_txt/chunk_385.txt
# Saved chunk 386 to extracted_txt/chunk_386.txt
# Saved chunk 387 to extracted_txt/chunk_387.txt
# Saved chunk 388 to extracted_txt/chunk_388.txt
# Saved chunk 389 to extracted_txt/chunk_389.txt
# Saved chunk 390 to extracted_txt/chunk_390.txt
# Saved chunk 391 to extracted_txt/chunk_391.txt
# Saved chunk 392 to extracted_txt/chunk_392.txt
# Saved chunk 393 to extracted_txt/chunk_393.txt
# Saved chunk 394 to extracted_txt/chunk_394.txt
# Saved chunk 395 to extracted_txt/chunk_395.txt
# Saved chunk 396 to extracted_txt/chunk_396.txt
# Saved chunk 397 to extracted_txt/chunk_397.txt
# Saved chunk 398 to extracted_txt/chunk_398.txt
# Saved chunk 399 to extracted_txt/chunk_399.txt
# Saved chunk 400 to extracted_txt/chunk_400.txt
# Saved chunk 401 to extracted_txt/chunk_401.txt
# Saved chunk 402 to extracted_txt/chunk_402.txt
# Saved chunk 403 to extracted_txt/chunk_403.txt
# Saved chunk 404 to extracted_txt/chunk_404.txt
# Saved chunk 405 to extracted_txt/chunk_405.txt
# Saved chunk 406 to extracted_txt/chunk_406.txt
# Saved chunk 407 to extracted_txt/chunk_407.txt
# Saved chunk 408 to extracted_txt/chunk_408.txt
# Saved chunk 409 to extracted_txt/chunk_409.txt
# Saved chunk 410 to extracted_txt/chunk_410.txt
# Saved chunk 411 to extracted_txt/chunk_411.txt
# Saved chunk 412 to extracted_txt/chunk_412.txt
# Saved chunk 413 to extracted_txt/chunk_413.txt
# Saved chunk 414 to extracted_txt/chunk_414.txt
# Saved chunk 415 to extracted_txt/chunk_415.txt
# Saved chunk 416 to extracted_txt/chunk_416.txt
# Saved chunk 417 to extracted_txt/chunk_417.txt
# Saved chunk 418 to extracted_txt/chunk_418.txt
# Saved chunk 419 to extracted_txt/chunk_419.txt
# Saved chunk 420 to extracted_txt/chunk_420.txt
# Saved chunk 421 to extracted_txt/chunk_421.txt
# Saved chunk 422 to extracted_txt/chunk_422.txt
# Saved chunk 423 to extracted_txt/chunk_423.txt
# Saved chunk 424 to extracted_txt/chunk_424.txt
# Saved chunk 425 to extracted_txt/chunk_425.txt
# Saved chunk 426 to extracted_txt/chunk_426.txt
# Saved chunk 427 to extracted_txt/chunk_427.txt
# Saved chunk 428 to extracted_txt/chunk_428.txt
# Saved chunk 429 to extracted_txt/chunk_429.txt
# Saved chunk 430 to extracted_txt/chunk_430.txt
# Saved chunk 431 to extracted_txt/chunk_431.txt
# Saved chunk 432 to extracted_txt/chunk_432.txt
# Saved chunk 433 to extracted_txt/chunk_433.txt
# Saved chunk 434 to extracted_txt/chunk_434.txt
# Saved chunk 435 to extracted_txt/chunk_435.txt
# Saved chunk 436 to extracted_txt/chunk_436.txt
# Saved chunk 437 to extracted_txt/chunk_437.txt
# Saved chunk 438 to extracted_txt/chunk_438.txt
# Saved chunk 439 to extracted_txt/chunk_439.txt
# Saved chunk 440 to extracted_txt/chunk_440.txt
# Saved chunk 441 to extracted_txt/chunk_441.txt
# Saved chunk 442 to extracted_txt/chunk_442.txt
# Saved chunk 443 to extracted_txt/chunk_443.txt
# Saved chunk 444 to extracted_txt/chunk_444.txt
# Saved chunk 445 to extracted_txt/chunk_445.txt
# Saved chunk 446 to extracted_txt/chunk_446.txt
# Saved chunk 447 to extracted_txt/chunk_447.txt
# Saved chunk 448 to extracted_txt/chunk_448.txt
# Saved chunk 449 to extracted_txt/chunk_449.txt
# Saved chunk 450 to extracted_txt/chunk_450.txt
# Saved chunk 451 to extracted_txt/chunk_451.txt
# Saved chunk 452 to extracted_txt/chunk_452.txt
# Saved chunk 453 to extracted_txt/chunk_453.txt
# Saved chunk 454 to extracted_txt/chunk_454.txt
# Saved chunk 455 to extracted_txt/chunk_455.txt
# Saved chunk 456 to extracted_txt/chunk_456.txt
# Saved chunk 457 to extracted_txt/chunk_457.txt
# Saved chunk 458 to extracted_txt/chunk_458.txt
# Saved chunk 459 to extracted_txt/chunk_459.txt
# Saved chunk 460 to extracted_txt/chunk_460.txt
# Saved chunk 461 to extracted_txt/chunk_461.txt
# Saved chunk 462 to extracted_txt/chunk_462.txt
# Saved chunk 463 to extracted_txt/chunk_463.txt
# Saved chunk 464 to extracted_txt/chunk_464.txt
# Saved chunk 465 to extracted_txt/chunk_465.txt
# Saved chunk 466 to extracted_txt/chunk_466.txt
# Saved chunk 467 to extracted_txt/chunk_467.txt
# Saved chunk 468 to extracted_txt/chunk_468.txt
# Saved chunk 469 to extracted_txt/chunk_469.txt
# Saved chunk 470 to extracted_txt/chunk_470.txt
# Saved chunk 471 to extracted_txt/chunk_471.txt
# Saved chunk 472 to extracted_txt/chunk_472.txt
# Saved chunk 473 to extracted_txt/chunk_473.txt
# Saved chunk 474 to extracted_txt/chunk_474.txt
# Saved chunk 475 to extracted_txt/chunk_475.txt
# Saved chunk 476 to extracted_txt/chunk_476.txt
# Saved chunk 477 to extracted_txt/chunk_477.txt
# Saved chunk 478 to extracted_txt/chunk_478.txt
# Saved chunk 479 to extracted_txt/chunk_479.txt
# Saved chunk 480 to extracted_txt/chunk_480.txt
# Saved chunk 481 to extracted_txt/chunk_481.txt
# Saved chunk 482 to extracted_txt/chunk_482.txt
# Saved chunk 483 to extracted_txt/chunk_483.txt
# Saved chunk 484 to extracted_txt/chunk_484.txt
# Saved chunk 485 to extracted_txt/chunk_485.txt
# Saved chunk 486 to extracted_txt/chunk_486.txt
# Saved chunk 487 to extracted_txt/chunk_487.txt
# Saved chunk 488 to extracted_txt/chunk_488.txt
# Saved chunk 489 to extracted_txt/chunk_489.txt
# Saved chunk 490 to extracted_txt/chunk_490.txt
# Saved chunk 491 to extracted_txt/chunk_491.txt
# Saved chunk 492 to extracted_txt/chunk_492.txt
# Saved chunk 493 to extracted_txt/chunk_493.txt
# Saved chunk 494 to extracted_txt/chunk_494.txt
# Saved chunk 495 to extracted_txt/chunk_495.txt
# Saved chunk 496 to extracted_txt/chunk_496.txt
# Saved chunk 497 to extracted_txt/chunk_497.txt
# Saved chunk 498 to extracted_txt/chunk_498.txt
# Saved chunk 499 to extracted_txt/chunk_499.txt
# Saved chunk 500 to extracted_txt/chunk_500.txt
# Saved chunk 501 to extracted_txt/chunk_501.txt
# Saved chunk 502 to extracted_txt/chunk_502.txt
# Saved chunk 503 to extracted_txt/chunk_503.txt
# Saved chunk 504 to extracted_txt/chunk_504.txt
# Saved chunk 505 to extracted_txt/chunk_505.txt
# Saved chunk 506 to extracted_txt/chunk_506.txt
# Saved chunk 507 to extracted_txt/chunk_507.txt
# Saved chunk 508 to extracted_txt/chunk_508.txt
# Saved chunk 509 to extracted_txt/chunk_509.txt
# Saved chunk 510 to extracted_txt/chunk_510.txt
# Saved chunk 511 to extracted_txt/chunk_511.txt
# Saved chunk 512 to extracted_txt/chunk_512.txt
# Saved chunk 513 to extracted_txt/chunk_513.txt
# Saved chunk 514 to extracted_txt/chunk_514.txt
# Saved chunk 515 to extracted_txt/chunk_515.txt
# Saved chunk 516 to extracted_txt/chunk_516.txt
# Saved chunk 517 to extracted_txt/chunk_517.txt
# Saved chunk 518 to extracted_txt/chunk_518.txt
# Saved chunk 519 to extracted_txt/chunk_519.txt
# Saved chunk 520 to extracted_txt/chunk_520.txt
# Saved chunk 521 to extracted_txt/chunk_521.txt
# Saved chunk 522 to extracted_txt/chunk_522.txt
# Saved chunk 523 to extracted_txt/chunk_523.txt
# Saved chunk 524 to extracted_txt/chunk_524.txt
# Saved chunk 525 to extracted_txt/chunk_525.txt
# Saved chunk 526 to extracted_txt/chunk_526.txt
# Saved chunk 527 to extracted_txt/chunk_527.txt
# Saved chunk 528 to extracted_txt/chunk_528.txt
# Saved chunk 529 to extracted_txt/chunk_529.txt
# Saved chunk 530 to extracted_txt/chunk_530.txt
# Saved chunk 531 to extracted_txt/chunk_531.txt
# Saved chunk 532 to extracted_txt/chunk_532.txt
# Saved chunk 533 to extracted_txt/chunk_533.txt
# Saved chunk 534 to extracted_txt/chunk_534.txt
# Saved chunk 535 to extracted_txt/chunk_535.txt
# Saved chunk 536 to extracted_txt/chunk_536.txt
# Saved chunk 537 to extracted_txt/chunk_537.txt
# Saved chunk 538 to extracted_txt/chunk_538.txt
# Saved chunk 539 to extracted_txt/chunk_539.txt
# Saved chunk 540 to extracted_txt/chunk_540.txt
# Saved chunk 541 to extracted_txt/chunk_541.txt
# Saved chunk 542 to extracted_txt/chunk_542.txt
# Saved chunk 543 to extracted_txt/chunk_543.txt
# Saved chunk 544 to extracted_txt/chunk_544.txt
# Saved chunk 545 to extracted_txt/chunk_545.txt
# Saved chunk 546 to extracted_txt/chunk_546.txt
# Saved chunk 547 to extracted_txt/chunk_547.txt
# Saved chunk 548 to extracted_txt/chunk_548.txt
# Saved chunk 549 to extracted_txt/chunk_549.txt
# Saved chunk 550 to extracted_txt/chunk_550.txt
# Saved chunk 551 to extracted_txt/chunk_551.txt
# Saved chunk 552 to extracted_txt/chunk_552.txt
# Saved chunk 553 to extracted_txt/chunk_553.txt
# Saved chunk 554 to extracted_txt/chunk_554.txt
# Saved chunk 555 to extracted_txt/chunk_555.txt
# Saved chunk 556 to extracted_txt/chunk_556.txt
# Saved chunk 557 to extracted_txt/chunk_557.txt
# Saved chunk 558 to extracted_txt/chunk_558.txt
# Saved chunk 559 to extracted_txt/chunk_559.txt
# Saved chunk 560 to extracted_txt/chunk_560.txt
# Saved chunk 561 to extracted_txt/chunk_561.txt
# Saved chunk 562 to extracted_txt/chunk_562.txt
# Saved chunk 563 to extracted_txt/chunk_563.txt
# Saved chunk 564 to extracted_txt/chunk_564.txt
# Saved chunk 565 to extracted_txt/chunk_565.txt
# Saved chunk 566 to extracted_txt/chunk_566.txt
# Saved chunk 567 to extracted_txt/chunk_567.txt
# Saved chunk 568 to extracted_txt/chunk_568.txt
# Saved chunk 569 to extracted_txt/chunk_569.txt
# Saved chunk 570 to extracted_txt/chunk_570.txt
# Saved chunk 571 to extracted_txt/chunk_571.txt
# Saved chunk 572 to extracted_txt/chunk_572.txt
# Saved chunk 573 to extracted_txt/chunk_573.txt
# Saved chunk 574 to extracted_txt/chunk_574.txt
# Saved chunk 575 to extracted_txt/chunk_575.txt
# Saved chunk 576 to extracted_txt/chunk_576.txt
# Saved chunk 577 to extracted_txt/chunk_577.txt
# Saved chunk 578 to extracted_txt/chunk_578.txt
# Saved chunk 579 to extracted_txt/chunk_579.txt
# Saved chunk 580 to extracted_txt/chunk_580.txt
# Saved chunk 581 to extracted_txt/chunk_581.txt
# Saved chunk 582 to extracted_txt/chunk_582.txt
# Saved chunk 583 to extracted_txt/chunk_583.txt
# Saved chunk 584 to extracted_txt/chunk_584.txt
# Saved chunk 585 to extracted_txt/chunk_585.txt
# Saved chunk 586 to extracted_txt/chunk_586.txt
# Saved chunk 587 to extracted_txt/chunk_587.txt
# Saved chunk 588 to extracted_txt/chunk_588.txt
# Saved chunk 589 to extracted_txt/chunk_589.txt
# Saved chunk 590 to extracted_txt/chunk_590.txt
# Saved chunk 591 to extracted_txt/chunk_591.txt
# Saved chunk 592 to extracted_txt/chunk_592.txt
# Saved chunk 593 to extracted_txt/chunk_593.txt
# Saved chunk 594 to extracted_txt/chunk_594.txt
# Saved chunk 595 to extracted_txt/chunk_595.txt
# Saved chunk 596 to extracted_txt/chunk_596.txt
# Saved chunk 597 to extracted_txt/chunk_597.txt
# Saved chunk 598 to extracted_txt/chunk_598.txt
# Saved chunk 599 to extracted_txt/chunk_599.txt
# Saved chunk 600 to extracted_txt/chunk_600.txt
# Saved chunk 601 to extracted_txt/chunk_601.txt
# Saved chunk 602 to extracted_txt/chunk_602.txt
# Saved chunk 603 to extracted_txt/chunk_603.txt
# Saved chunk 604 to extracted_txt/chunk_604.txt
# Saved chunk 605 to extracted_txt/chunk_605.txt
# Saved chunk 606 to extracted_txt/chunk_606.txt
# Saved chunk 607 to extracted_txt/chunk_607.txt
# Saved chunk 608 to extracted_txt/chunk_608.txt
# Saved chunk 609 to extracted_txt/chunk_609.txt
# Saved chunk 610 to extracted_txt/chunk_610.txt
# Saved chunk 611 to extracted_txt/chunk_611.txt
# Saved chunk 612 to extracted_txt/chunk_612.txt
# Saved chunk 613 to extracted_txt/chunk_613.txt
# Saved chunk 614 to extracted_txt/chunk_614.txt
# Saved chunk 615 to extracted_txt/chunk_615.txt
# Saved chunk 616 to extracted_txt/chunk_616.txt
# Saved chunk 617 to extracted_txt/chunk_617.txt
# Saved chunk 618 to extracted_txt/chunk_618.txt
# Saved chunk 619 to extracted_txt/chunk_619.txt
# Saved chunk 620 to extracted_txt/chunk_620.txt
# Saved chunk 621 to extracted_txt/chunk_621.txt
# Saved chunk 622 to extracted_txt/chunk_622.txt
# Saved chunk 623 to extracted_txt/chunk_623.txt
# Saved chunk 624 to extracted_txt/chunk_624.txt
# Saved chunk 625 to extracted_txt/chunk_625.txt
# Saved chunk 626 to extracted_txt/chunk_626.txt
# Saved chunk 627 to extracted_txt/chunk_627.txt
# Saved chunk 628 to extracted_txt/chunk_628.txt
# Saved chunk 629 to extracted_txt/chunk_629.txt
# Saved chunk 630 to extracted_txt/chunk_630.txt
# Saved chunk 631 to extracted_txt/chunk_631.txt
# Saved chunk 632 to extracted_txt/chunk_632.txt
# Saved chunk 633 to extracted_txt/chunk_633.txt
# Saved chunk 634 to extracted_txt/chunk_634.txt
# Saved chunk 635 to extracted_txt/chunk_635.txt
# Saved chunk 636 to extracted_txt/chunk_636.txt
# Saved chunk 637 to extracted_txt/chunk_637.txt
# Saved chunk 638 to extracted_txt/chunk_638.txt
# Saved chunk 639 to extracted_txt/chunk_639.txt
# Saved chunk 640 to extracted_txt/chunk_640.txt
# Saved chunk 641 to extracted_txt/chunk_641.txt
# Saved chunk 642 to extracted_txt/chunk_642.txt
# Saved chunk 643 to extracted_txt/chunk_643.txt
# Saved chunk 644 to extracted_txt/chunk_644.txt
# Saved chunk 645 to extracted_txt/chunk_645.txt
# Saved chunk 646 to extracted_txt/chunk_646.txt
# Saved chunk 647 to extracted_txt/chunk_647.txt
# Saved chunk 648 to extracted_txt/chunk_648.txt
# Saved chunk 649 to extracted_txt/chunk_649.txt
# Saved chunk 650 to extracted_txt/chunk_650.txt
# Saved chunk 651 to extracted_txt/chunk_651.txt
# Saved chunk 652 to extracted_txt/chunk_652.txt
# Saved chunk 653 to extracted_txt/chunk_653.txt
# Saved chunk 654 to extracted_txt/chunk_654.txt
# Saved chunk 655 to extracted_txt/chunk_655.txt
# Saved chunk 656 to extracted_txt/chunk_656.txt
# Saved chunk 657 to extracted_txt/chunk_657.txt
# Saved chunk 658 to extracted_txt/chunk_658.txt
# Saved chunk 659 to extracted_txt/chunk_659.txt
# Saved chunk 660 to extracted_txt/chunk_660.txt
# Saved chunk 661 to extracted_txt/chunk_661.txt
# Saved chunk 662 to extracted_txt/chunk_662.txt
# Saved chunk 663 to extracted_txt/chunk_663.txt
# Saved chunk 664 to extracted_txt/chunk_664.txt
# Saved chunk 665 to extracted_txt/chunk_665.txt
# Saved chunk 666 to extracted_txt/chunk_666.txt
# Saved chunk 667 to extracted_txt/chunk_667.txt
# Saved chunk 668 to extracted_txt/chunk_668.txt
# Saved chunk 669 to extracted_txt/chunk_669.txt
# Saved chunk 670 to extracted_txt/chunk_670.txt
# Saved chunk 671 to extracted_txt/chunk_671.txt
# Saved chunk 672 to extracted_txt/chunk_672.txt
# Saved chunk 673 to extracted_txt/chunk_673.txt
# Saved chunk 674 to extracted_txt/chunk_674.txt
# Saved chunk 675 to extracted_txt/chunk_675.txt
# Saved chunk 676 to extracted_txt/chunk_676.txt
# Saved chunk 677 to extracted_txt/chunk_677.txt
# Saved chunk 678 to extracted_txt/chunk_678.txt
# Saved chunk 679 to extracted_txt/chunk_679.txt
# Saved chunk 680 to extracted_txt/chunk_680.txt
# Saved chunk 681 to extracted_txt/chunk_681.txt
# Saved chunk 682 to extracted_txt/chunk_682.txt
# Saved chunk 683 to extracted_txt/chunk_683.txt
# Saved chunk 684 to extracted_txt/chunk_684.txt
# Saved chunk 685 to extracted_txt/chunk_685.txt
# Saved chunk 686 to extracted_txt/chunk_686.txt
# Saved chunk 687 to extracted_txt/chunk_687.txt
# Saved chunk 688 to extracted_txt/chunk_688.txt
# Saved chunk 689 to extracted_txt/chunk_689.txt
# Saved chunk 690 to extracted_txt/chunk_690.txt
# Saved chunk 691 to extracted_txt/chunk_691.txt
# Saved chunk 692 to extracted_txt/chunk_692.txt
# Saved chunk 693 to extracted_txt/chunk_693.txt
# Saved chunk 694 to extracted_txt/chunk_694.txt
# Saved chunk 695 to extracted_txt/chunk_695.txt
# Saved chunk 696 to extracted_txt/chunk_696.txt
# Saved chunk 697 to extracted_txt/chunk_697.txt
# Saved chunk 698 to extracted_txt/chunk_698.txt
# Saved chunk 699 to extracted_txt/chunk_699.txt
# Saved chunk 700 to extracted_txt/chunk_700.txt
# Saved chunk 701 to extracted_txt/chunk_701.txt
# Saved chunk 702 to extracted_txt/chunk_702.txt
# Saved chunk 703 to extracted_txt/chunk_703.txt
# Saved chunk 704 to extracted_txt/chunk_704.txt
# Saved chunk 705 to extracted_txt/chunk_705.txt
# Saved chunk 706 to extracted_txt/chunk_706.txt
# Saved chunk 707 to extracted_txt/chunk_707.txt
# Saved chunk 708 to extracted_txt/chunk_708.txt
# Saved chunk 709 to extracted_txt/chunk_709.txt
# Saved chunk 710 to extracted_txt/chunk_710.txt
# Saved chunk 711 to extracted_txt/chunk_711.txt
# Saved chunk 712 to extracted_txt/chunk_712.txt
# Saved chunk 713 to extracted_txt/chunk_713.txt
# Saved chunk 714 to extracted_txt/chunk_714.txt
# Saved chunk 715 to extracted_txt/chunk_715.txt
# Saved chunk 716 to extracted_txt/chunk_716.txt
# Saved chunk 717 to extracted_txt/chunk_717.txt
# Saved chunk 718 to extracted_txt/chunk_718.txt
# Saved chunk 719 to extracted_txt/chunk_719.txt
# Saved chunk 720 to extracted_txt/chunk_720.txt
# Saved chunk 721 to extracted_txt/chunk_721.txt
# Saved chunk 722 to extracted_txt/chunk_722.txt
# Saved chunk 723 to extracted_txt/chunk_723.txt
# Saved chunk 724 to extracted_txt/chunk_724.txt
# Saved chunk 725 to extracted_txt/chunk_725.txt
# Saved chunk 726 to extracted_txt/chunk_726.txt
# Saved chunk 727 to extracted_txt/chunk_727.txt
# Saved chunk 728 to extracted_txt/chunk_728.txt
# Saved chunk 729 to extracted_txt/chunk_729.txt
# Saved chunk 730 to extracted_txt/chunk_730.txt
# Saved chunk 731 to extracted_txt/chunk_731.txt
# Saved chunk 732 to extracted_txt/chunk_732.txt
# Saved chunk 733 to extracted_txt/chunk_733.txt
# Saved chunk 734 to extracted_txt/chunk_734.txt
# Saved chunk 735 to extracted_txt/chunk_735.txt
# Saved chunk 736 to extracted_txt/chunk_736.txt
# Saved chunk 737 to extracted_txt/chunk_737.txt
# Saved chunk 738 to extracted_txt/chunk_738.txt
# Saved chunk 739 to extracted_txt/chunk_739.txt
# Saved chunk 740 to extracted_txt/chunk_740.txt
# Saved chunk 741 to extracted_txt/chunk_741.txt
# Saved chunk 742 to extracted_txt/chunk_742.txt
# Saved chunk 743 to extracted_txt/chunk_743.txt
# Saved chunk 744 to extracted_txt/chunk_744.txt
# Saved chunk 745 to extracted_txt/chunk_745.txt
# Saved chunk 746 to extracted_txt/chunk_746.txt
# Saved chunk 747 to extracted_txt/chunk_747.txt
# Saved chunk 748 to extracted_txt/chunk_748.txt
# Saved chunk 749 to extracted_txt/chunk_749.txt
# Saved chunk 750 to extracted_txt/chunk_750.txt
# Saved chunk 751 to extracted_txt/chunk_751.txt
# Saved chunk 752 to extracted_txt/chunk_752.txt
# Saved chunk 753 to extracted_txt/chunk_753.txt
# Saved chunk 754 to extracted_txt/chunk_754.txt
# Saved chunk 755 to extracted_txt/chunk_755.txt
# Saved chunk 756 to extracted_txt/chunk_756.txt
# Saved chunk 757 to extracted_txt/chunk_757.txt
# Saved chunk 758 to extracted_txt/chunk_758.txt
# Saved chunk 759 to extracted_txt/chunk_759.txt
# Saved chunk 760 to extracted_txt/chunk_760.txt
# Saved chunk 761 to extracted_txt/chunk_761.txt
# Saved chunk 762 to extracted_txt/chunk_762.txt
# Saved chunk 763 to extracted_txt/chunk_763.txt
# Saved chunk 764 to extracted_txt/chunk_764.txt
# Saved chunk 765 to extracted_txt/chunk_765.txt
# Saved chunk 766 to extracted_txt/chunk_766.txt
# Saved chunk 767 to extracted_txt/chunk_767.txt
# Saved chunk 768 to extracted_txt/chunk_768.txt
# Saved chunk 769 to extracted_txt/chunk_769.txt
# Saved chunk 770 to extracted_txt/chunk_770.txt
# Saved chunk 771 to extracted_txt/chunk_771.txt
# Saved chunk 772 to extracted_txt/chunk_772.txt
# Saved chunk 773 to extracted_txt/chunk_773.txt
# Saved chunk 774 to extracted_txt/chunk_774.txt
# Saved chunk 775 to extracted_txt/chunk_775.txt
# Saved chunk 776 to extracted_txt/chunk_776.txt
# Saved chunk 777 to extracted_txt/chunk_777.txt
# Saved chunk 778 to extracted_txt/chunk_778.txt
# Saved chunk 779 to extracted_txt/chunk_779.txt
# Saved chunk 780 to extracted_txt/chunk_780.txt
# Saved chunk 781 to extracted_txt/chunk_781.txt
# Saved chunk 782 to extracted_txt/chunk_782.txt
# Saved chunk 783 to extracted_txt/chunk_783.txt
# Saved chunk 784 to extracted_txt/chunk_784.txt
# Saved chunk 785 to extracted_txt/chunk_785.txt
# Saved chunk 786 to extracted_txt/chunk_786.txt
# Saved chunk 787 to extracted_txt/chunk_787.txt
# Saved chunk 788 to extracted_txt/chunk_788.txt
# Saved chunk 789 to extracted_txt/chunk_789.txt
# Saved chunk 790 to extracted_txt/chunk_790.txt
# Saved chunk 791 to extracted_txt/chunk_791.txt
# Saved chunk 792 to extracted_txt/chunk_792.txt
# Saved chunk 793 to extracted_txt/chunk_793.txt
# Saved chunk 794 to extracted_txt/chunk_794.txt
# Saved chunk 795 to extracted_txt/chunk_795.txt
# Saved chunk 796 to extracted_txt/chunk_796.txt
# Saved chunk 797 to extracted_txt/chunk_797.txt
# Saved chunk 798 to extracted_txt/chunk_798.txt
# Saved chunk 799 to extracted_txt/chunk_799.txt
# Saved chunk 800 to extracted_txt/chunk_800.txt
# Saved chunk 801 to extracted_txt/chunk_801.txt
# Saved chunk 802 to extracted_txt/chunk_802.txt
# Saved chunk 803 to extracted_txt/chunk_803.txt
# Saved chunk 804 to extracted_txt/chunk_804.txt
# Saved chunk 805 to extracted_txt/chunk_805.txt
# Saved chunk 806 to extracted_txt/chunk_806.txt
# Saved chunk 807 to extracted_txt/chunk_807.txt
# Saved chunk 808 to extracted_txt/chunk_808.txt
# Saved chunk 809 to extracted_txt/chunk_809.txt
# Saved chunk 810 to extracted_txt/chunk_810.txt
# Saved chunk 811 to extracted_txt/chunk_811.txt
# Saved chunk 812 to extracted_txt/chunk_812.txt
# Saved chunk 813 to extracted_txt/chunk_813.txt
# Saved chunk 814 to extracted_txt/chunk_814.txt
# Saved chunk 815 to extracted_txt/chunk_815.txt
# Saved chunk 816 to extracted_txt/chunk_816.txt
# Saved chunk 817 to extracted_txt/chunk_817.txt
# Saved chunk 818 to extracted_txt/chunk_818.txt
# Saved chunk 819 to extracted_txt/chunk_819.txt
# Saved chunk 820 to extracted_txt/chunk_820.txt
# Saved chunk 821 to extracted_txt/chunk_821.txt
# Saved chunk 822 to extracted_txt/chunk_822.txt
# Saved chunk 823 to extracted_txt/chunk_823.txt
# Saved chunk 824 to extracted_txt/chunk_824.txt
# Saved chunk 825 to extracted_txt/chunk_825.txt
# Saved chunk 826 to extracted_txt/chunk_826.txt
# Saved chunk 827 to extracted_txt/chunk_827.txt
# Saved chunk 828 to extracted_txt/chunk_828.txt
# Saved chunk 829 to extracted_txt/chunk_829.txt
# Saved chunk 830 to extracted_txt/chunk_830.txt
# Saved chunk 831 to extracted_txt/chunk_831.txt
# Saved chunk 832 to extracted_txt/chunk_832.txt
# Saved chunk 833 to extracted_txt/chunk_833.txt
# Saved chunk 834 to extracted_txt/chunk_834.txt
# Saved chunk 835 to extracted_txt/chunk_835.txt
# Saved chunk 836 to extracted_txt/chunk_836.txt
# Saved chunk 837 to extracted_txt/chunk_837.txt
# Saved chunk 838 to extracted_txt/chunk_838.txt
# Saved chunk 839 to extracted_txt/chunk_839.txt
# Saved chunk 840 to extracted_txt/chunk_840.txt
# Saved chunk 841 to extracted_txt/chunk_841.txt
# Saved chunk 842 to extracted_txt/chunk_842.txt
# Saved chunk 843 to extracted_txt/chunk_843.txt
# Saved chunk 844 to extracted_txt/chunk_844.txt
# Saved chunk 845 to extracted_txt/chunk_845.txt
# Saved chunk 846 to extracted_txt/chunk_846.txt
# Saved chunk 847 to extracted_txt/chunk_847.txt
# Saved chunk 848 to extracted_txt/chunk_848.txt
# Saved chunk 849 to extracted_txt/chunk_849.txt
# Saved chunk 850 to extracted_txt/chunk_850.txt
# Saved chunk 851 to extracted_txt/chunk_851.txt
# Saved chunk 852 to extracted_txt/chunk_852.txt
# Saved chunk 853 to extracted_txt/chunk_853.txt
# Saved chunk 854 to extracted_txt/chunk_854.txt
# Saved chunk 855 to extracted_txt/chunk_855.txt
# Saved chunk 856 to extracted_txt/chunk_856.txt
# Saved chunk 857 to extracted_txt/chunk_857.txt
# Saved chunk 858 to extracted_txt/chunk_858.txt
# Saved chunk 859 to extracted_txt/chunk_859.txt
# Saved chunk 860 to extracted_txt/chunk_860.txt
# Saved chunk 861 to extracted_txt/chunk_861.txt
# Saved chunk 862 to extracted_txt/chunk_862.txt
# Saved chunk 863 to extracted_txt/chunk_863.txt
# Saved chunk 864 to extracted_txt/chunk_864.txt
# Saved chunk 865 to extracted_txt/chunk_865.txt
# Saved chunk 866 to extracted_txt/chunk_866.txt
# Saved chunk 867 to extracted_txt/chunk_867.txt
# Saved chunk 868 to extracted_txt/chunk_868.txt
# Saved chunk 869 to extracted_txt/chunk_869.txt
# Saved chunk 870 to extracted_txt/chunk_870.txt
# Saved chunk 871 to extracted_txt/chunk_871.txt
# Saved chunk 872 to extracted_txt/chunk_872.txt
# Saved chunk 873 to extracted_txt/chunk_873.txt
# Saved chunk 874 to extracted_txt/chunk_874.txt
# Saved chunk 875 to extracted_txt/chunk_875.txt
# Saved chunk 876 to extracted_txt/chunk_876.txt
# Saved chunk 877 to extracted_txt/chunk_877.txt
# Saved chunk 878 to extracted_txt/chunk_878.txt
# Saved chunk 879 to extracted_txt/chunk_879.txt
# Saved chunk 880 to extracted_txt/chunk_880.txt
# Saved chunk 881 to extracted_txt/chunk_881.txt
# Saved chunk 882 to extracted_txt/chunk_882.txt
# Saved chunk 883 to extracted_txt/chunk_883.txt
# Saved chunk 884 to extracted_txt/chunk_884.txt
# Saved chunk 885 to extracted_txt/chunk_885.txt
# Saved chunk 886 to extracted_txt/chunk_886.txt
# Saved chunk 887 to extracted_txt/chunk_887.txt
# Saved chunk 888 to extracted_txt/chunk_888.txt
# Saved chunk 889 to extracted_txt/chunk_889.txt
# Saved chunk 890 to extracted_txt/chunk_890.txt
# Saved chunk 891 to extracted_txt/chunk_891.txt
# Saved chunk 892 to extracted_txt/chunk_892.txt
# Saved chunk 893 to extracted_txt/chunk_893.txt
# Saved chunk 894 to extracted_txt/chunk_894.txt
# Saved chunk 895 to extracted_txt/chunk_895.txt
# Saved chunk 896 to extracted_txt/chunk_896.txt
# Saved chunk 897 to extracted_txt/chunk_897.txt
# Saved chunk 898 to extracted_txt/chunk_898.txt
# Saved chunk 899 to extracted_txt/chunk_899.txt
# Saved chunk 900 to extracted_txt/chunk_900.txt
# Saved chunk 901 to extracted_txt/chunk_901.txt
# Saved chunk 902 to extracted_txt/chunk_902.txt
# Saved chunk 903 to extracted_txt/chunk_903.txt
# Saved chunk 904 to extracted_txt/chunk_904.txt
# Saved chunk 905 to extracted_txt/chunk_905.txt
# Saved chunk 906 to extracted_txt/chunk_906.txt
# Saved chunk 907 to extracted_txt/chunk_907.txt
# Saved chunk 908 to extracted_txt/chunk_908.txt
# Saved chunk 909 to extracted_txt/chunk_909.txt
# Saved chunk 910 to extracted_txt/chunk_910.txt
# Saved chunk 911 to extracted_txt/chunk_911.txt
# Saved chunk 912 to extracted_txt/chunk_912.txt
# Saved chunk 913 to extracted_txt/chunk_913.txt
# Saved chunk 914 to extracted_txt/chunk_914.txt
# Saved chunk 915 to extracted_txt/chunk_915.txt
# Saved chunk 916 to extracted_txt/chunk_916.txt
# Saved chunk 917 to extracted_txt/chunk_917.txt
# Saved chunk 918 to extracted_txt/chunk_918.txt
# Saved chunk 919 to extracted_txt/chunk_919.txt
# Saved chunk 920 to extracted_txt/chunk_920.txt
# Saved chunk 921 to extracted_txt/chunk_921.txt
# Saved chunk 922 to extracted_txt/chunk_922.txt
# Saved chunk 923 to extracted_txt/chunk_923.txt
# Saved chunk 924 to extracted_txt/chunk_924.txt
# Saved chunk 925 to extracted_txt/chunk_925.txt
# Saved chunk 926 to extracted_txt/chunk_926.txt
# Saved chunk 927 to extracted_txt/chunk_927.txt
# Saved chunk 928 to extracted_txt/chunk_928.txt
# Saved chunk 929 to extracted_txt/chunk_929.txt
# Saved chunk 930 to extracted_txt/chunk_930.txt
# Saved chunk 931 to extracted_txt/chunk_931.txt
# Saved chunk 932 to extracted_txt/chunk_932.txt
# Saved chunk 933 to extracted_txt/chunk_933.txt
# Saved chunk 934 to extracted_txt/chunk_934.txt
# Saved chunk 935 to extracted_txt/chunk_935.txt
# Saved chunk 936 to extracted_txt/chunk_936.txt
# Saved chunk 937 to extracted_txt/chunk_937.txt
# Saved chunk 938 to extracted_txt/chunk_938.txt
# Saved chunk 939 to extracted_txt/chunk_939.txt
# Saved chunk 940 to extracted_txt/chunk_940.txt
# Saved chunk 941 to extracted_txt/chunk_941.txt
# Saved chunk 942 to extracted_txt/chunk_942.txt
# Saved chunk 943 to extracted_txt/chunk_943.txt
# Saved chunk 944 to extracted_txt/chunk_944.txt
# Saved chunk 945 to extracted_txt/chunk_945.txt
# Saved chunk 946 to extracted_txt/chunk_946.txt
# Saved chunk 947 to extracted_txt/chunk_947.txt
# Saved chunk 948 to extracted_txt/chunk_948.txt
# Saved chunk 949 to extracted_txt/chunk_949.txt
# Saved chunk 950 to extracted_txt/chunk_950.txt
# Saved chunk 951 to extracted_txt/chunk_951.txt
# Saved chunk 952 to extracted_txt/chunk_952.txt
# Saved chunk 953 to extracted_txt/chunk_953.txt
# Saved chunk 1324 to extracted_txt/chunk_1324.txt
# Saved chunk 1325 to extracted_txt/chunk_1325.txt
# Saved chunk 1326 to extracted_txt/chunk_1326.txt
# Saved chunk 1327 to extracted_txt/chunk_1327.txt
# Saved chunk 1328 to extracted_txt/chunk_1328.txt
# Saved chunk 1329 to extracted_txt/chunk_1329.txt
# Saved chunk 1330 to extracted_txt/chunk_1330.txt
# Saved chunk 1331 to extracted_txt/chunk_1331.txt
# Saved chunk 1332 to extracted_txt/chunk_1332.txt

# %%
import ssl
import nltk

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/giacomo/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from kg_gen import KGGen
import json

# Initialize KGGen as before
kg = KGGen(
    model="ollama_chat/llama3:4b",
    temperature=0.0,
    api_key="sk-no-key-needed",
)

graph_list = []
for idx, chunk in enumerate(list_docs_md):
    if not chunk.strip():
        print(f"Skipping empty chunk {idx}")
        continue
    print(f"Processing chunk {idx} of length:", len(chunk))
    print("Chunk preview:", chunk[:500])
    try:
        # You could try without cluster if needed, or adjust as desired
        graph = kg.generate(input_data=chunk, context="Business regulations", cluster=True)
    except Exception as e:
        print(f"Error processing chunk {idx}: {e}")
        continue
    # Check that the response contains the expected output
    if not getattr(graph, "relations", None):
        print(f"Chunk {idx} produced an unexpected response and is being skipped.")
        continue
    print("Individual Graph:", graph)
    graph_list.append(graph)

if graph_list:
    aggregated_graph = kg.aggregate(graph_list)
    print("Aggregated Graph:", aggregated_graph)
    with open("aggregated_graph.json", "w", encoding="utf-8") as outfile:
        json.dump(aggregated_graph, outfile, ensure_ascii=False, indent=4)
    print("Graph saved to aggregated_graph.json")
else:
    print("No valid graphs were generated.")
# Out:
# Processing chunk 0 of length: 201
# Chunk preview:
# ## Page 1
#
# ### Text on Page 1
# REPUBBLICA ITALIANA ANNO XLV BARI, 8 AGOSTO 2014 n. 109BOLLETTINO UFFICIALE della Regione Puglia Leggi e regolamenti regionali VOLUME PRIMO 2014.08. 19  09:09:08 +02'00'
# 12:42:41 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:42:41 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:42:58 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:42:58 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:04 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:04 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:10 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:10 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:12 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:13 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:15 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:15 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:19 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:19 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# 12:43:20 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# Individual Graph: entities={'Regione Puglia'} edges={'edges'} relations={('Regione Puglia', 'edges', 'Regione Puglia')} entity_clusters={'Regione Puglia': {'109BOLLETTINO UFFICIALE', 'BARI', '09:09:08', "02'00'", 'Regione Puglia', '2014.08.19', 'REPUBBLICA ITALIANA', '8 AGOSTO 2014'}} edge_clusters={'edges': {'è', 'della'}}
# Processing chunk 1 of length: 1813
# Chunk preview:
# ## Page 2
#
# ### Text on Page 2
# Il Bollettino Ufficiale della Regione Puglia si pubblica con frequenza infrasettimanale ed è diviso in due parti. Nella parte I sono pubblicati: a) sentenze ed ordinanze della Corte Costituzionale riguardanti leggi della Regione Puglia; b) ricorsi e sentenze di Organi giurisdizionali che prevedono un coinvolgimento della Regione Puglia;c) leggi e regolamenti regionali;d) deliberazioni del Consiglio Regionale riguardanti la convalida degli eletti;e) atti e circolari
# 12:43:21 - LiteLLM:ERROR: litellm_logging.py:3482 - Error creating standard logging object - __annotations__
# Traceback (most recent call last):
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/litellm_logging.py", line 3464, in get_standard_logging_object_payload
#     model_parameters=ModelParamHelper.get_standard_logging_model_parameters(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 28, in get_standard_logging_model_parameters
#     ModelParamHelper._get_relevant_args_to_use_for_logging()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 45, in _get_relevant_args_to_use_for_logging
#     all_openai_llm_api_params = ModelParamHelper._get_all_llm_api_params()
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 65, in _get_all_llm_api_params
#     ModelParamHelper._get_litellm_supported_transcription_kwargs()
#   File "/Users/giacomo/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/model_param_helper.py", line 126, in _get_litellm_supported_transcription_kwargs
#     return set(TranscriptionCreateParams.__annotations__.keys())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py", line 1318, in __getattr__
#     raise AttributeError(attr)
# AttributeError: __annotations__
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      17 print("Chunk preview:", chunk[:500])
#      18 try:
#      19     # You could try without cluster if needed, or adjust as desired
# ---> 20     graph = kg.generate(input_data=chunk, context="Business regulations", cluster=True)
#      21 except Exception as e:
#      22     print(f"Error processing chunk {idx}: {e}")
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/kg_gen/kg_gen.py:133, in KGGen.generate(self, input_data, model, api_key, api_base, context, chunk_size, cluster, temperature, output_folder)
#     125   self.init_model(
#     126     model=model or self.model,
#     127     temperature=temperature or self.temperature,
#     128     api_key=api_key or self.api_key,
#     129     api_base=api_base or self.api_base,
#     130   )
#     132 if not chunk_size:
# --> 133   entities = get_entities(self.dspy, processed_input, is_conversation=is_conversation)
#     134   relations = get_relations(self.dspy, processed_input, entities, is_conversation=is_conversation)
#     135 else:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/kg_gen/steps/_1_get_entities.py:25, in get_entities(dspy, input_data, is_conversation)
#      22 else:
#      23   extract = dspy.Predict(TextEntities)
# ---> 25 result = extract(source_text=input_data)
#      26 return result.entities
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/predict/predict.py:85, in Predict.__call__(self, *args, **kwargs)
#      82 if args:
#      83     raise ValueError(self._get_positional_args_error_message())
# ---> 85 return super().__call__(**kwargs)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/primitives/program.py:32, in Module.__call__(self, *args, **kwargs)
#      29         output.set_lm_usage(usage_tracker.get_total_tokens())
#      30         return output
# ---> 32 return self.forward(*args, **kwargs)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/predict/predict.py:146, in Predict.forward(self, **kwargs)
#     144 else:
#     145     with settings.context(send_stream=None):
# --> 146         completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     148 return self._forward_postprocess(completions, signature, **kwargs)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/adapters/chat_adapter.py:42, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      33 def __call__(
#      34     self,
#      35     lm: LM,
#    (...)     39     inputs: dict[str, Any],
#      40 ) -> list[dict[str, Any]]:
#      41     try:
# ---> 42         return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      43     except Exception as e:
#      44         # fallback to JSONAdapter
#      45         from dspy.adapters.json_adapter import JSONAdapter
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/adapters/base.py:51, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      41 def __call__(
#      42     self,
#      43     lm: "LM",
#    (...)     47     inputs: dict[str, Any],
#      48 ) -> list[dict[str, Any]]:
#      49     inputs = self.format(signature, demos, inputs)
# ---> 51     outputs = lm(messages=inputs, **lm_kwargs)
#      52     return self._call_post_process(outputs, signature)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/clients/base_lm.py:88, in BaseLM.__call__(self, prompt, messages, **kwargs)
#      86 @with_callbacks
#      87 def __call__(self, prompt=None, messages=None, **kwargs):
# ---> 88     response = self.forward(prompt=prompt, messages=messages, **kwargs)
#      89     outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#      91     return outputs
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/clients/lm.py:127, in LM.forward(self, prompt, messages, **kwargs)
#     124 completion = litellm_completion if self.model_type == "chat" else litellm_text_completion
#     125 completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache, enable_memory_cache)
# --> 127 results = completion(
#     128     request=dict(model=self.model, messages=messages, **kwargs),
#     129     num_retries=self.num_retries,
#     130     cache=litellm_cache_args,
#     131 )
#     133 if any(c.finish_reason == "length" for c in results["choices"]):
#     134     logger.warning(
#     135         f"LM response was truncated due to exceeding max_tokens={self.kwargs['max_tokens']}. "
#     136         "You can inspect the latest LM interactions with `dspy.inspect_history()`. "
#    (...)    139         " if the reason for truncation is repetition."
#     140     )
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/clients/cache.py:232, in request_cache.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     229     return cached_result
#     231 # Otherwise, compute and store the result
# --> 232 result = fn(*args, **kwargs)
#     233 # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#     234 cache.put(modified_request, result, ignored_args_for_cache_key, enable_memory_cache)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/dspy/clients/lm.py:304, in litellm_completion(request, num_retries, cache)
#     302 stream_completion = _get_stream_completion_fn(request, cache, sync=True)
#     303 if stream_completion is None:
# --> 304     return litellm.completion(
#     305         cache=cache,
#     306         num_retries=num_retries,
#     307         retry_strategy="exponential_backoff_retry",
#     308         **request,
#     309     )
#     311 return stream_completion()
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/utils.py:1091, in client.<locals>.wrapper(*args, **kwargs)
#    1089         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1090 # MODEL CALL
# -> 1091 result = original_function(*args, **kwargs)
#    1092 end_time = datetime.datetime.now()
#    1093 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/main.py:2848, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2841 api_key = (
#    2842     api_key
#    2843     or litellm.ollama_key
#    2844     or os.environ.get("OLLAMA_API_KEY")
#    2845     or litellm.api_key
#    2846 )
#    2847 ## LOGGING
# -> 2848 generator = ollama_chat.get_ollama_response(
#    2849     api_base=api_base,
#    2850     api_key=api_key,
#    2851     model=model,
#    2852     messages=messages,
#    2853     optional_params=optional_params,
#    2854     logging_obj=logging,
#    2855     acompletion=acompletion,
#    2856     model_response=model_response,
#    2857     encoding=encoding,
#    2858     client=client,
#    2859 )
#    2860 if acompletion is True or optional_params.get("stream", False) is True:
#    2861     return generator
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/llms/ollama_chat.py:313, in get_ollama_response(model_response, messages, optional_params, model, logging_obj, api_base, api_key, acompletion, encoding, client)
#     311 if client is not None and isinstance(client, HTTPHandler):
#     312     sync_client = client
# --> 313 response = sync_client.post(
#     314     url=url,
#     315     json=data,
#     316     headers=headers,
#     317 )
#     318 if response.status_code != 200:
#     319     raise OllamaError(status_code=response.status_code, message=response.text)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/litellm/llms/custom_httpx/http_handler.py:537, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     533 else:
#     534     req = self.client.build_request(
#     535         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     536     )
# --> 537 response = self.client.send(req, stream=stream)
#     538 response.raise_for_status()
#     539 return response
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/kg+llm_task2_nlp/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
